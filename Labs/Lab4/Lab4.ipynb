# %% [markdown]
# # Lab 4

# %% [markdown]
# Dataset Selection & Justification
# - What dataset did your group choose, and why?
# - What makes this dataset interesting or relevant?
#
# Data Accessibility & Cleaning
# - How difficult was it to load the data into Python?
# - What state is the data in?
# - Did your group need to perform any significant cleaning?
#
# Exploratory Analysis & Visualization
# - What types of analysis did your group carry out?
# - Compute summary statistics
# - Include visualizations to help explain your findings (using Matplotlib, Seaborn, Plotly, or Bokeh)
#
# Insights & Conclusions
# - What did your group learn from the dataset?
# - What key takeaways can you share from your analysis?

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
df = pd.read_csv('Motor_Vehicle_Registrations_Dashboard_data.csv')
df = df[df["state"] != "Puerto Rico"]
df['state'] = df['state'].str.replace('\(2\)', '', regex=True)
df
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\('
# <>:6: SyntaxWarning: invalid escape sequence '\('
# C:\Users\brown\AppData\Local\Temp\ipykernel_11152\1183492002.py:6: SyntaxWarning: invalid escape sequence '\('
#   df['state'] = df['state'].str.replace('\(2\)', '', regex=True)
#       year           state       Auto      Bus      Truck  Motorcycle
# 0     1900         Alabama       40.0      0.0        0.0         0.0
# 1     1900          Alaska        0.0      0.0        0.0         0.0
# 2     1900         Arizona       20.0      0.0        0.0         0.0
# 3     1900        Arkansas       20.0      0.0        0.0         0.0
# 4     1900      California      780.0      0.0        0.0         0.0
# ...    ...             ...        ...      ...        ...         ...
# 6288  2020        Virginia  3057254.0  35463.0  4329294.0    184441.0
# 6289  2020     Washington   2800370.0  24172.0  4211411.0    221448.0
# ...

# %%
# @title year vs Bus

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['year']
  ys = series['Bus']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('year', ascending=True)
df_averages = df_sorted.groupby('year', as_index=False)['Bus'].mean()
_plot_series(df_averages, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('year')
_ = plt.ylabel('Bus')

# %%
# @title year vs Auto

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['year']
  ys = series['Auto']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('year', ascending=True)
df_averages = df_sorted.groupby('year', as_index=False)['Auto'].mean()
_plot_series(df_averages, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('year')
_ = plt.ylabel('Auto')

# %%
# @title year vs Motorcycle

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['year']
  ys = series['Motorcycle']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('year', ascending=True)
df_averages = df_sorted.groupby('year', as_index=False)['Motorcycle'].mean()
_plot_series(df_averages, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('year')
_ = plt.ylabel('Motorcycle')
